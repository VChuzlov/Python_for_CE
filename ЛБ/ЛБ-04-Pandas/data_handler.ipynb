# %%
import pandas as pd

# %%
df = pd.read_csv('db.csv')

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0    KeyR  RackettZraValue  BWRSParameterB0Value  \
# 0                0         0.0     1.0          0.28927                   NaN
# 1                1         1.0     2.0          0.28085                   NaN
# 2                2         2.0     3.0          0.27657                   NaN
# 3                3         3.0     4.0          0.27493                   NaN
# 4                4         4.0     5.0          0.27292                   NaN
# ...            ...         ...     ...              ...                   ...
# 1803          2068      1812.0  3097.0          0.25762                   NaN
# 1804          2069      1820.0  3105.0          0.25486                   NaN
# 1805          2070      1821.0  3106.0          0.25581                   NaN
# 1806          2071      1838.0  3123.0          0.25545                   NaN
# 1807          2072      1839.0  3124.0          0.25004                   NaN
#
# ...

# %%
df.dropna(axis='columns', how='all')
# Out:
#       Unnamed: 0.1  Unnamed: 0    KeyR  RackettZraValue BWRSParameterA0Value  \
# 0                0         0.0     1.0          0.28927                  NaN
# 1                1         1.0     2.0          0.28085                  NaN
# 2                2         2.0     3.0          0.27657                  NaN
# 3                3         3.0     4.0          0.27493                  NaN
# 4                4         4.0     5.0          0.27292                  NaN
# ...            ...         ...     ...              ...                  ...
# 1803          2068      1812.0  3097.0          0.25762                  NaN
# 1804          2069      1820.0  3105.0          0.25486                  NaN
# 1805          2070      1821.0  3106.0          0.25581                  NaN
# 1806          2071      1838.0  3123.0          0.25545                  NaN
# 1807          2072      1839.0  3124.0          0.25004                  NaN
#
# ...
